# %%
dataset = [['Milk' , 'Onion' , 'Nutmeg' , 'Kidney Beans' , 'Eggs' , 'Yogurt'],
           ['Dill' , 'Onion' , 'Nutmeg' , 'Kidney Beans' , 'Eggs' , 'Yogurt'],
           ['Milk' , 'Apple' , 'Kidney Beans' , 'Eggs'],
           ['Milk' , 'Unicorn' , 'Corn' , 'Kidney Beans' , 'Yogurt'],
           ['Corn' , 'Onion' , 'Onion' , 'Kidney Beans' , 'Eggs' , 'Ice cream']]

print(dataset)
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'], ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'], ['Milk', 'Apple', 'Kidney Beans', 'Eggs'], ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'], ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Eggs', 'Ice cream']]

# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_items = te.fit(dataset)
print(te_items.columns_)
# Out:
# ['Apple', 'Corn', 'Dill', 'Eggs', 'Ice cream', 'Kidney Beans', 'Milk', 'Nutmeg', 'Onion', 'Unicorn', 'Yogurt']

# %%
df = pd.DataFrame(te.transform(dataset) , columns = te_items.columns_)
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  ...   Milk  Nutmeg  Onion  Unicorn  Yogurt
# 0  False  False  False   True      False  ...   True    True   True    False    True
# 1  False  False   True   True      False  ...  False    True   True    False    True
# 2   True  False  False   True      False  ...   True   False  False    False   False
# 3  False   True  False  False      False  ...   True   False  False     True    True
# 4  False   True  False   True       True  ...  False   False   True    False   False
#
# [5 rows x 11 columns]

# %%
#Identify the most frequent itemsets

from mlxtend.frequent_patterns import apriori
frequent_itemsets = apriori(df, use_colnames=True,min_support=0.4)
frequent_itemsets
# Out:
#     support                                     itemsets
# 0       0.4                                       (Corn)
# 1       0.8                                       (Eggs)
# 2       1.0                               (Kidney Beans)
# 3       0.6                                       (Milk)
# 4       0.4                                     (Nutmeg)
# 5       0.6                                      (Onion)
# 6       0.6                                     (Yogurt)
# 7       0.4                         (Corn, Kidney Beans)
# 8       0.8                         (Eggs, Kidney Beans)
# 9       0.4                                 (Eggs, Milk)
# 10      0.4                               (Eggs, Nutmeg)
# 11      0.6                                (Eggs, Onion)
# 12      0.4                               (Eggs, Yogurt)
# 13      0.6                         (Kidney Beans, Milk)
# 14      0.4                       (Kidney Beans, Nutmeg)
# ...

# %%
#Calculate confidence & Lift values for frequent itemsets

from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets , metric='lift' , min_threshold=1)

rules
# Out:
# /usr/local/lib/python3.12/dist-packages/mlxtend/frequent_patterns/association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
#         antecedents  ... kulczynski
# 0            (Corn)  ...   0.700000
# 1    (Kidney Beans)  ...   0.700000
# 2            (Eggs)  ...   0.900000
# 3    (Kidney Beans)  ...   0.900000
# 4            (Eggs)  ...   0.750000
# ..              ...  ...        ...
# 183        (Nutmeg)  ...   1.000000
# 184         (Onion)  ...   0.833333
# 185          (Eggs)  ...   0.750000
# 186        (Yogurt)  ...   0.833333
# 187  (Kidney Beans)  ...   0.700000
#
# [188 rows x 14 columns]

# %%
r1 = rules[['antecedents','consequents','support', 'confidence', 'lift']]
r1['antecedents'] = r1['antecedents'].apply(lambda x : list(x))
r1['consequents'] = r1['consequents'].apply(lambda x : list(x))
r1.to_csv('recommendar.csv')
# Out:
# /tmp/ipython-input-526354249.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r1['antecedents'] = r1['antecedents'].apply(lambda x : list(x))
# /tmp/ipython-input-526354249.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r1['consequents'] = r1['consequents'].apply(lambda x : list(x))

# %%
df_recommend = pd.read_csv('/content/recommendar.csv' , index_col = 0)
df_recommend = df_recommend.sort_values('lift', ascending = False)
df_recommend
# Out:
#                                antecedents  ... lift
# 47                      ['Eggs', 'Yogurt']  ...  2.5
# 50                              ['Nutmeg']  ...  2.5
# 134                     ['Eggs', 'Yogurt']  ...  2.5
# 135                     ['Eggs', 'Nutmeg']  ...  2.5
# 131            ['Eggs', 'Onion', 'Yogurt']  ...  2.5
# ..                                     ...  ...  ...
# 127                       ['Kidney Beans']  ...  1.0
# 154                       ['Kidney Beans']  ...  1.0
# 147          ['Nutmeg', 'Onion', 'Yogurt']  ...  1.0
# 158  ['Eggs', 'Yogurt', 'Nutmeg', 'Onion']  ...  1.0
# 187                       ['Kidney Beans']  ...  1.0
#
# [188 rows x 5 columns]

# %%
purchased_items = "['Nutmeg']"

df_recommend[df_recommend['antecedents'] == purchased_items].consequents
# Out:
# 50                              ['Eggs', 'Yogurt']
# 156            ['Kidney Beans', 'Onion', 'Yogurt']
# 183    ['Eggs', 'Kidney Beans', 'Yogurt', 'Onion']
# 142                    ['Eggs', 'Onion', 'Yogurt']
# 114             ['Eggs', 'Kidney Beans', 'Yogurt']
# 86                             ['Onion', 'Yogurt']
# 20                                      ['Yogurt']
# 44                               ['Eggs', 'Onion']
# 18                                       ['Onion']
# 68                       ['Kidney Beans', 'Onion']
# 100              ['Eggs', 'Kidney Beans', 'Onion']
# 74                      ['Kidney Beans', 'Yogurt']
# 31                        ['Eggs', 'Kidney Beans']
# 5                                         ['Eggs']
# 11                                ['Kidney Beans']
# Name: consequents, dtype: object
